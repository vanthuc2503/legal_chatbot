# %%
# !pip install -r requirements.txt
# Out:
# Collecting gradio==5.22.0
#   Downloading gradio-5.22.0-py3-none-any.whl (46.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 47.7 MB/s eta 0:00:0000:0100:01
# Collecting faiss-gpu==1.7.2
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 32.2 MB/s eta 0:00:0000:0100:01
# Collecting transformers==4.49.0
#   Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 87.6 MB/s eta 0:00:0000:0100:01
# Collecting sentence_transformers==3.4.1
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.9/275.9 KB 90.3 MB/s eta 0:00:00
# Collecting accelerate==1.5.2
#   Downloading accelerate-1.5.2-py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 KB 83.1 MB/s eta 0:00:00
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 68.1 MB/s eta 0:00:0000:0100:01
# Collecting safehttpx<0.2.0,>=0.1.6
#   Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Collecting starlette<1.0,>=0.40.0
#   Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 KB 54.6 MB/s eta 0:00:00
# Collecting typer<1.0,>=0.12
#   Downloading typer-0.15.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 KB 31.2 MB/s eta 0:00:00
# Collecting groovy~=0.1
#   Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Collecting ffmpy
#   Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Collecting httpx>=0.24.1
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 55.1 MB/s eta 0:00:00
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 KB 73.3 MB/s eta 0:00:00
# Collecting orjson~=3.0
#   Downloading orjson-3.10.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.3/130.3 KB 77.7 MB/s eta 0:00:00
# Collecting semantic-version~=2.0
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0
#   Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (6.0.2)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pydantic>=2.0
#   Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 KB 83.1 MB/s eta 0:00:00
# Collecting tomlkit<0.14.0,>=0.12.0
#   Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: jinja2<4.0 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (2.1.5)
# Collecting fastapi<1.0,>=0.115.2
#   Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 KB 64.1 MB/s eta 0:00:00
# Collecting pandas<3.0,>=1.0
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 81.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow<12.0,>=8.0 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (11.0.0)
# Collecting ruff>=0.9.3
#   Downloading ruff-0.11.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 83.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions~=4.0 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (4.12.2)
# Collecting python-multipart>=0.0.18
#   Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Collecting aiofiles<24.0,>=22.0
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /venv/main/lib/python3.10/site-packages (from gradio==5.22.0->-r requirements.txt (line 1)) (0.28.1)
# Collecting gradio-client==1.8.0
#   Downloading gradio_client-1.8.0-py3-none-any.whl (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 KB 99.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /venv/main/lib/python3.10/site-packages (from transformers==4.49.0->-r requirements.txt (line 3)) (3.17.0)
# Requirement already satisfied: requests in /venv/main/lib/python3.10/site-packages (from transformers==4.49.0->-r requirements.txt (line 3)) (2.32.3)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 91.7 MB/s eta 0:00:00
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 KB 128.4 MB/s eta 0:00:00
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 87.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /venv/main/lib/python3.10/site-packages (from transformers==4.49.0->-r requirements.txt (line 3)) (4.67.1)
# Collecting scipy
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 52.4 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 85.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: torch>=1.11.0 in /venv/main/lib/python3.10/site-packages (from sentence_transformers==3.4.1->-r requirements.txt (line 4)) (2.5.1+cu121)
# Requirement already satisfied: psutil in /venv/main/lib/python3.10/site-packages (from accelerate==1.5.2->-r requirements.txt (line 5)) (6.1.1)
# Collecting websockets<16.0,>=10.0
#   Downloading websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 KB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /venv/main/lib/python3.10/site-packages (from gradio-client==1.8.0->gradio==5.22.0->-r requirements.txt (line 1)) (2025.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /venv/main/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio==5.22.0->-r requirements.txt (line 1)) (1.2.2)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /venv/main/lib/python3.10/site-packages (from anyio<5.0,>=3.0->gradio==5.22.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: certifi in /venv/main/lib/python3.10/site-packages (from httpx>=0.24.1->gradio==5.22.0->-r requirements.txt (line 1)) (2025.1.31)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 KB 52.6 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 KB 115.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /venv/main/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==5.22.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 KB 120.7 MB/s eta 0:00:00
# Collecting pydantic-core==2.27.2
#   Downloading pydantic_core-2.27.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 96.0 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: triton==3.1.0 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: networkx in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.0.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: sympy==1.13.1 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (11.4.5.107)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /venv/main/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /venv/main/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers==3.4.1->-r requirements.txt (line 4)) (1.3.0)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 KB 67.1 MB/s eta 0:00:00
# Collecting rich>=10.11.0
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 KB 87.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests->transformers==4.49.0->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests->transformers==4.49.0->-r requirements.txt (line 3)) (2.3.0)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 KB 118.7 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.5 in /venv/main/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.22.0->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /venv/main/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.22.0->-r requirements.txt (line 1)) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, pydub, faiss-gpu, websockets, tzdata, tomlkit, threadpoolctl, sniffio, shellingham, semantic-version, safetensors, ruff, regex, python-multipart, pydantic-core, orjson, numpy, mdurl, joblib, h11, groovy, ffmpy, click, annotated-types, aiofiles, uvicorn, scipy, pydantic, pandas, markdown-it-py, httpcore, anyio, tokenizers, starlette, scikit-learn, rich, httpx, typer, transformers, safehttpx, gradio-client, fastapi, accelerate, sentence_transformers, gradio
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# Successfully installed accelerate-1.5.2 aiofiles-23.2.1 annotated-types-0.7.0 anyio-4.9.0 click-8.1.8 faiss-gpu-1.7.2 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.22.0 gradio-client-1.8.0 groovy-0.1.2 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 joblib-1.4.2 markdown-it-py-3.0.0 mdurl-0.1.2 numpy-1.26.4 orjson-3.10.15 pandas-2.2.3 pydantic-2.10.6 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 pytz-2025.1 regex-2024.11.6 rich-13.9.4 ruff-0.11.2 safehttpx-0.1.6 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.2 semantic-version-2.10.0 sentence_transformers-3.4.1 shellingham-1.5.4 sniffio-1.3.1 starlette-0.46.1 threadpoolctl-3.6.0 tokenizers-0.21.1 tomlkit-0.13.2 transformers-4.49.0 typer-0.15.2 tzdata-2025.2 uvicorn-0.34.0 websockets-15.0.1

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# !ollama pull gemma3:12b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling manifest      ▏    0 B/8.1 GB
# pulling manifest      ▏    0 B/8.1 GB
# pulling manifest      ▏    0 B/8.1 GB
# pulling manifest      ▏ 4.3 MB/8.1 GB
# pulling manifest      ▏  14 MB/8.1 GB
# pulling manifest      ▏  21 MB/8.1 GB
# pulling manifest      ▏  37 MB/8.1 GB
# pulling manifest      ▏  45 MB/8.1 GB
# pulling manifest      ▏  45 MB/8.1 GB
# pulling manifest      ▏  56 MB/8.1 GB
# pulling manifest      ▏  64 MB/8.1 GB   64 MB/s    2m5s
# pulling manifest      ▏  69 MB/8.1 GB   64 MB/s    2m5s
# pulling manifest      ▏  87 MB/8.1 GB   64 MB/s    2m5s
# pulling manifest      ▏ 100 MB/8.1 GB   64 MB/s    2m5s
# pulling manifest      ▏ 107 MB/8.1 GB   64 MB/s    2m5s
# pulling manifest      ▏ 124 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 136 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 142 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 157 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 172 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 179 MB/8.1 GB   64 MB/s    2m4s
# pulling manifest      ▏ 195 MB/8.1 GB   93 MB/s   1m25s
# pulling manifest      ▏ 204 MB/8.1 GB   93 MB/s   1m25s
# pulling manifest      ▏ 208 MB/8.1 GB   93 MB/s   1m25s
# pulling manifest      ▏ 219 MB/8.1 GB   93 MB/s   1m25s
# pulling manifest      ▏ 237 MB/8.1 GB   93 MB/s   1m25s
# pulling manifest      ▏ 245 MB/8.1 GB   93 MB/s   1m24s
# pulling manifest      ▏ 258 MB/8.1 GB   93 MB/s   1m24s
# pulling manifest      ▏ 272 MB/8.1 GB   93 MB/s   1m24s
# pulling manifest      ▏ 279 MB/8.1 GB   93 MB/s   1m24s
# pulling manifest      ▏ 293 MB/8.1 GB   93 MB/s   1m24s
# pulling manifest      ▏ 307 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 314 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 327 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 342 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 349 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 363 MB/8.1 GB   99 MB/s   1m18s
# pulling manifest      ▏ 377 MB/8.1 GB   99 MB/s   1m17s
# pulling manifest      ▏ 384 MB/8.1 GB   99 MB/s   1m17s
# pulling manifest      ▏ 398 MB/8.1 GB   99 MB/s   1m17s
# pulling manifest      ▏ 412 MB/8.1 GB   99 MB/s   1m17s
# pulling manifest      ▏ 418 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 432 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 447 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 454 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 469 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 483 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 491 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 493 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 500 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 504 MB/8.1 GB  104 MB/s   1m13s
# pulling manifest      ▏ 516 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 530 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 540 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 553 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 567 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 574 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 589 MB/8.1 GB  103 MB/s   1m13s
# pulling manifest      ▏ 602 MB/8.1 GB  103 MB/s   1m12s
# pulling manifest      ▏ 609 MB/8.1 GB  103 MB/s   1m12s
# pulling manifest      ▏ 626 MB/8.1 GB  103 MB/s   1m12s
# pulling manifest      ▏ 638 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 646 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 657 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 671 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 679 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 694 MB/8.1 GB  106 MB/s   1m10s
# pulling manifest      ▏ 708 MB/8.1 GB  106 MB/s    1m9s
# pulling manifest      ▏ 714 MB/8.1 GB  106 MB/s    1m9s
# pulling manifest      ▏ 729 MB/8.1 GB  106 MB/s    1m9s
# pulling manifest      ▏ 744 MB/8.1 GB  106 MB/s    1m9s
# pulling manifest      ▏ 750 MB/8.1 GB  106 MB/s    1m9s
# pulling manifest      ▏ 764 MB/8.1 GB  108 MB/s    1m8s
# pulling manifest      ▏ 777 MB/8.1 GB  108 MB/s    1m8s
# pulling manifest      ▏ 786 MB/8.1 GB  108 MB/s    1m8s
# pulling manifest      ▏ 800 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 813 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 819 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 833 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 848 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 855 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 869 MB/8.1 GB  108 MB/s    1m7s
# pulling manifest      ▏ 883 MB/8.1 GB  109 MB/s    1m6s
# pulling manifest      ▏ 891 MB/8.1 GB  109 MB/s    1m6s
# pulling manifest      ▏ 907 MB/8.1 GB  109 MB/s    1m6s
# pulling manifest      ▏ 919 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 927 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 940 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 956 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 963 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 974 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 987 MB/8.1 GB  109 MB/s    1m5s
# pulling manifest      ▏ 994 MB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.0 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.0 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.0 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.0 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.1 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.1 GB/8.1 GB  110 MB/s    1m4s
# pulling manifest      ▏ 1.1 GB/8.1 GB  110 MB/s    1m3s
# pulling manifest      ▏ 1.1 GB/8.1 GB  110 MB/s    1m3s
# pulling manifest      ▏ 1.1 GB/8.1 GB  110 MB/s    1m3s
# pulling manifest      ▏ 1.1 GB/8.1 GB  117 MB/s    1m0s
# pulling manifest      ▏ 1.1 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.1 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.1 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  117 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.2 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     59s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     58s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     58s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     58s
# pulling manifest      ▏ 1.3 GB/8.1 GB  116 MB/s     58s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.4 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     57s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.5 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     56s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.6 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  117 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     55s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.7 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     54s
# pulling manifest      ▏ 1.8 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 1.9 GB/8.1 GB  116 MB/s     53s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.0 GB/8.1 GB  116 MB/s     52s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     52s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.1 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  117 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     51s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.2 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.3 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.3 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.3 GB/8.1 GB  116 MB/s     50s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.3 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  117 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  117 MB/s     48s
# pulling manifest      ▏ 2.4 GB/8.1 GB  116 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  116 MB/s     49s
# pulling manifest      ▏ 2.4 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.4 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.4 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.5 GB/8.1 GB  116 MB/s     48s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.6 GB/8.1 GB  116 MB/s     47s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     46s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.7 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     45s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.8 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     44s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 2.9 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     43s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.0 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     42s
# pulling manifest      ▏ 3.1 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.2 GB/8.1 GB  119 MB/s     41s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.3 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     40s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.4 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  119 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.5 GB/8.1 GB  117 MB/s     39s
# pulling manifest      ▏ 3.6 GB/8.1 GB  117 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  117 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  117 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.6 GB/8.1 GB  118 MB/s     38s
# pulling manifest      ▏ 3.7 GB/8.1 GB  118 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  118 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  118 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  118 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  118 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.7 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     37s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     36s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     36s
# pulling manifest      ▏ 3.8 GB/8.1 GB  117 MB/s     36s
# pulling manifest      ▏ 3.8 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.8 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     36s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 3.9 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     35s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.0 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     34s
# pulling manifest      ▏ 4.1 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.2 GB/8.1 GB  118 MB/s     33s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.3 GB/8.1 GB  118 MB/s     32s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  118 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.4 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     31s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     30s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     30s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     30s
# pulling manifest      ▏ 4.5 GB/8.1 GB  117 MB/s     30s
# pulling manifest      ▏ 4.5 GB/8.1 GB  119 MB/s     30s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.6 GB/8.1 GB  119 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     29s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     28s
# pulling manifest      ▏ 4.7 GB/8.1 GB  118 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  118 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  118 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     28s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.8 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  119 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  118 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  118 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  118 MB/s     27s
# pulling manifest      ▏ 4.9 GB/8.1 GB  118 MB/s     27s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.0 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     26s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     25s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     25s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     25s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     25s
# pulling manifest      ▏ 5.1 GB/8.1 GB  118 MB/s     25s
# pulling manifest      ▏ 5.1 GB/8.1 GB  119 MB/s     25s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     25s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     25s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     25s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.2 GB/8.1 GB  119 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     24s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.3 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     23s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.4 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     22s
# pulling manifest      ▏ 5.5 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.6 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     21s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  118 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  119 MB/s     20s
# pulling manifest      ▏ 5.7 GB/8.1 GB  119 MB/s     20s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     20s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     20s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  119 MB/s     19s
# pulling manifest      ▏ 5.8 GB/8.1 GB  118 MB/s     19s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     19s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     19s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     19s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  118 MB/s     18s
# pulling manifest      ▏ 5.9 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.0 GB/8.1 GB  116 MB/s     18s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest      ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest █    ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest █    ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest █    ▏ 6.1 GB/8.1 GB  116 MB/s     17s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  116 MB/s     17s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  116 MB/s     16s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     17s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     17s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.2 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     16s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.3 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  115 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.4 GB/8.1 GB  113 MB/s     15s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.5 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     14s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest █    ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.6 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     13s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     12s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     12s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     12s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  113 MB/s     12s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.7 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     12s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.8 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     11s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     10s
# pulling manifest ██   ▏ 6.9 GB/8.1 GB  110 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s     10s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s      9s
# pulling manifest ██   ▏ 7.0 GB/8.1 GB  112 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  112 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  112 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ██   ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ███  ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ███  ▏ 7.1 GB/8.1 GB  111 MB/s      9s
# pulling manifest ███  ▏ 7.1 GB/8.1 GB  111 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  111 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  111 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  111 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  113 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  113 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  113 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  113 MB/s      8s
# pulling manifest ███  ▏ 7.2 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  113 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  112 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  112 MB/s      7s
# pulling manifest ███  ▏ 7.3 GB/8.1 GB  112 MB/s      7s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      7s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      7s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  112 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  115 MB/s      6s
# pulling manifest ███  ▏ 7.4 GB/8.1 GB  115 MB/s      6s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  115 MB/s      5s
# pulling manifest ███  ▏ 7.5 GB/8.1 GB  114 MB/s      5s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      5s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      5s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      5s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  114 MB/s      4s
# pulling manifest ███  ▏ 7.6 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.6 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      4s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      3s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      3s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  111 MB/s      3s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.7 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  112 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      3s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      2s
# pulling manifest ████ ▏ 7.8 GB/8.1 GB  105 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  105 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  105 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB  100 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   90 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 7.9 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      2s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   82 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.0 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      1s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   79 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   75 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   75 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   75 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   75 MB/s      0s
# pulling manifest ████ ▏ 8.1 GB/8.1 GB   75 MB/s      0s
# pulling manifest █████▏ 8.1 GB
# pulling manifest █████▏ 8.1 GB
# pulling manifest █████▏ 8.1 GB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest   ▏    0 B/ 358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest   ▏    0 B/ 358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling manifest ██▏  358 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest     0 B/8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest     0 B/8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest     0 B/8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest     0 B/8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling manifest  8.4 KB
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling manifest  0 B/  55 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling manifest 55 B
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# ...
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# verifying sha256 digest ⠙ pulling manifest
# pulling adca500fad9b... 100% ▕████████████████▏ 8.1 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9031f81160b9... 100% ▕████████████████▏  490 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !ollama pull gemma3:27b
# Out:
# pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling manifest      ▏    0 B/ 17 GB
# pulling manifest      ▏    0 B/ 17 GB
# pulling manifest      ▏ 1.5 MB/ 17 GB
# pulling manifest      ▏ 6.1 MB/ 17 GB
# pulling manifest      ▏  17 MB/ 17 GB
# pulling manifest      ▏  30 MB/ 17 GB
# pulling manifest      ▏  46 MB/ 17 GB
# pulling manifest      ▏  53 MB/ 17 GB
# pulling manifest      ▏  67 MB/ 17 GB
# pulling manifest      ▏  81 MB/ 17 GB
# pulling manifest      ▏  88 MB/ 17 GB   88 MB/s   3m15s
# pulling manifest      ▏ 100 MB/ 17 GB   88 MB/s   3m15s
# pulling manifest      ▏ 113 MB/ 17 GB   88 MB/s   3m15s
# pulling manifest      ▏ 120 MB/ 17 GB   88 MB/s   3m15s
# pulling manifest      ▏ 135 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 148 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 156 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 169 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 184 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 190 MB/ 17 GB   88 MB/s   3m14s
# pulling manifest      ▏ 205 MB/ 17 GB  102 MB/s   2m47s
# pulling manifest      ▏ 220 MB/ 17 GB  102 MB/s   2m47s
# pulling manifest      ▏ 226 MB/ 17 GB  102 MB/s   2m47s
# pulling manifest      ▏ 240 MB/ 17 GB  102 MB/s   2m47s
# pulling manifest      ▏ 254 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 261 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 276 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 290 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 298 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 313 MB/ 17 GB  102 MB/s   2m46s
# pulling manifest      ▏ 326 MB/ 17 GB  108 MB/s   2m37s
# pulling manifest      ▏ 334 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 346 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 360 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 368 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 382 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 392 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 395 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 406 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 418 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 425 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 441 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 455 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 462 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 476 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 490 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 498 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 513 MB/ 17 GB  108 MB/s   2m36s
# pulling manifest      ▏ 526 MB/ 17 GB  108 MB/s   2m35s
# pulling manifest      ▏ 532 MB/ 17 GB  108 MB/s   2m35s
# pulling manifest      ▏ 547 MB/ 17 GB  108 MB/s   2m35s
# pulling manifest      ▏ 561 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 568 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 582 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 596 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 603 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 617 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 631 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 637 MB/ 17 GB  110 MB/s   2m31s
# pulling manifest      ▏ 652 MB/ 17 GB  110 MB/s   2m30s
# pulling manifest      ▏ 669 MB/ 17 GB  110 MB/s   2m30s
# pulling manifest      ▏ 674 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 687 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 702 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 708 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 723 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 737 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 744 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 757 MB/ 17 GB  112 MB/s   2m28s
# pulling manifest      ▏ 772 MB/ 17 GB  112 MB/s   2m27s
# pulling manifest      ▏ 779 MB/ 17 GB  112 MB/s   2m27s
# pulling manifest      ▏ 793 MB/ 17 GB  113 MB/s   2m26s
# pulling manifest      ▏ 808 MB/ 17 GB  113 MB/s   2m26s
# pulling manifest      ▏ 814 MB/ 17 GB  113 MB/s   2m26s
# pulling manifest      ▏ 831 MB/ 17 GB  113 MB/s   2m26s
# pulling manifest      ▏ 845 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 852 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 866 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 877 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 883 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 898 MB/ 17 GB  113 MB/s   2m25s
# pulling manifest      ▏ 915 MB/ 17 GB  114 MB/s   2m24s
# pulling manifest      ▏ 921 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 935 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 950 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 955 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 972 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 985 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 993 MB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 1.0 GB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 1.0 GB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 1.0 GB/ 17 GB  114 MB/s   2m23s
# pulling manifest      ▏ 1.0 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m22s
# pulling manifest      ▏ 1.1 GB/ 17 GB  114 MB/s   2m21s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m17s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m17s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m17s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m17s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m17s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.2 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m16s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.3 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m15s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.4 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  118 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m15s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m15s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m15s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.5 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  117 MB/s   2m14s
# pulling manifest      ▏ 1.6 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.6 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.6 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.6 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m15s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.7 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m14s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.8 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 1.9 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m13s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.0 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m12s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m11s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m11s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m11s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m11s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.1 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.2 GB/ 17 GB  116 MB/s   2m10s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.3 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m9s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.4 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m8s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.5 GB/ 17 GB  116 MB/s    2m7s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.6 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.7 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.7 GB/ 17 GB  118 MB/s    2m4s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m3s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m3s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m3s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m3s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m3s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.7 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m2s
# pulling manifest      ▏ 2.8 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 2.9 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m1s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m0s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m0s
# pulling manifest      ▏ 3.0 GB/ 17 GB  119 MB/s    2m0s
# pulling manifest      ▏ 3.0 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.0 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.1 GB/ 17 GB  118 MB/s    2m0s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  118 MB/s   1m59s
# pulling manifest      ▏ 3.2 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m1s
# pulling manifest      ▏ 3.3 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s    2m0s
# pulling manifest      ▏ 3.4 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.5 GB/ 17 GB  116 MB/s   1m59s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.6 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m58s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m57s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m57s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m57s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m57s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.7 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.8 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m56s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 3.9 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m55s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.0 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m54s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.1 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m53s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.2 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  116 MB/s   1m52s
# pulling manifest      ▏ 4.3 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.3 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.3 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m49s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.4 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m48s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.5 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m47s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.6 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m46s
# pulling manifest      ▏ 4.7 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.8 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m45s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 4.9 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m44s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.0 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m43s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.1 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m42s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m41s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m41s
# pulling manifest      ▏ 5.2 GB/ 17 GB  119 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  119 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.3 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.4 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.4 GB/ 17 GB  118 MB/s   1m41s
# pulling manifest      ▏ 5.4 GB/ 17 GB  118 MB/s   1m40s
# pulling manifest      ▏ 5.4 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.4 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.4 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.4 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.4 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m40s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.5 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.6 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.6 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.6 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.6 GB/ 17 GB  119 MB/s   1m39s
# pulling manifest      ▏ 5.6 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.6 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.6 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.6 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m40s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.7 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.8 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m39s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 5.9 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m38s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.0 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m37s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.1 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m36s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.2 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m35s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.3 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m34s
# pulling manifest      ▏ 6.4 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.5 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m33s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.6 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.7 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.7 GB/ 17 GB  116 MB/s   1m32s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m30s
# pulling manifest      ▏ 6.7 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.8 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m29s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m28s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m28s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m28s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m28s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m28s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 6.9 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  118 MB/s   1m27s
# pulling manifest      ▏ 7.0 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.0 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m26s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.1 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.2 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m25s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.3 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m24s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.4 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m23s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.5 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m22s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.6 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m21s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.7 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m20s
# pulling manifest      ▏ 7.8 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 7.9 GB/ 17 GB  119 MB/s   1m19s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.0 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m18s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.1 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m17s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.2 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  119 MB/s   1m16s
# pulling manifest      ▏ 8.3 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.3 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.3 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m17s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m16s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m16s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m16s
# pulling manifest      ▏ 8.4 GB/ 17 GB  117 MB/s   1m16s
# pulling manifest      ▏ 8.4 GB/ 17 GB  116 MB/s   1m17s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.5 GB/ 17 GB  116 MB/s   1m16s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.6 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m15s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.7 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m14s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.8 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m13s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 8.9 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m12s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.0 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m11s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.1 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s   1m10s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.2 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.3 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.4 GB/ 17 GB  116 MB/s    1m9s
# pulling manifest      ▏ 9.4 GB/ 17 GB  116 MB/s    1m8s
# pulling manifest      ▏ 9.4 GB/ 17 GB  116 MB/s    1m8s
# pulling manifest      ▏ 9.4 GB/ 17 GB  116 MB/s    1m8s
# pulling manifest      ▏ 9.4 GB/ 17 GB  119 MB/s    1m7s
# pulling manifest      ▏ 9.4 GB/ 17 GB  119 MB/s    1m7s
# pulling manifest      ▏ 9.4 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.4 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.4 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m6s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.5 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  119 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  118 MB/s    1m5s
# pulling manifest      ▏ 9.6 GB/ 17 GB  118 MB/s    1m5s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m5s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m5s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.7 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m4s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m3s
# pulling manifest      ▏ 9.8 GB/ 17 GB  118 MB/s    1m3s
# ...
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# pulling manifest
# pulling afa0ea2ef463... 100% ▕████████████████▏  17 GB
# pulling e0a42594d802... 100% ▕████████████████▏  358 B
# pulling dd084c7d92a3... 100% ▕████████████████▏ 8.4 KB
# pulling 0a74a8735bf3... 100% ▕████████████████▏   55 B
# pulling 9e5186b1ce17... 100% ▕████████████████▏  490 B
# verifying sha256 digest
# writing manifest
# success

# %%
import os
import re
import numpy as np
import pandas as pd
import gradio as gr
import torch
import faiss
import requests
import torch.nn.functional as F

from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSequenceClassification
from sentence_transformers import SentenceTransformer

# Load models

tokenizer = AutoTokenizer.from_pretrained("phmtung/dpl302m-model")
query_decomposition = AutoModelForCausalLM.from_pretrained("phmtung/dpl302m-model", device_map='cuda')
query_decomposition.eval()

embedder = SentenceTransformer('dangvantuan/vietnamese-document-embedding', trust_remote_code=True)

classifi_model_path = "./phobert_finetuned"
classifi_model = AutoModelForSequenceClassification.from_pretrained(classifi_model_path, device_map='cuda')
classifi_tokenizer = AutoTokenizer.from_pretrained(classifi_model_path)
classifi_model.eval()

# Load faiss index and datastore
index = faiss.read_index('faiss.index')
df = pd.read_csv("chunks.csv")
df_folder = 'data_with_label'
faiss_index_folder = 'faiss_index'

dfs = sorted([f for f in os.listdir(df_folder) if not f.startswith('.')])
index_files = sorted([f for f in os.listdir(faiss_index_folder) if not f.startswith('.')])

for i in range(1, 6):
    globals()[f"df{i}"] = pd.read_csv(f"{df_folder}/{dfs[i-1]}")
    globals()[f"index{i}"] = faiss.read_index(f"{faiss_index_folder}/{index_files[i-1]}")

# Chat history storage
chat_history = []

###  HELPER FUNCTIONS  ###

def predict_label(query):
    """Predict law label of a given query
    Args:
        text (str): input query
    Returns:
        int: predicted label
    """
    inputs = classifi_tokenizer(query, return_tensors="pt", truncation=True, padding="max_length", max_length=128).to('cuda')
    
    with torch.no_grad():
        outputs = classifi_model(**inputs)
        
    logits = outputs.logits
    probs = F.softmax(logits, dim=-1)
    
    predicted_label = torch.argmax(probs, dim=-1).item()

    label_mapping = {0: "Trẻ em", 1: "Bình đẳng giới", 2: "Dân số", 3: "Hôn nhân và gia đình", 4: "Phòng, chống bạo lực gia đình", 5: "Khác"}

    return predicted_label+1

def get_embedding(query):
    """Get embedding of a given query
    Args:
        query (str): input query
    Returns:
        np.array: query embedding
    """
    return embedder.encode(query)


def similarity_search_with_filter(query, label, top_k=3):
    """Search for similar articles given a query and label
    Args:
        query (str): input query
        label (int): predicted label
        top_k (int): number of articles to return
    Returns:
        list[str]: list of articles
    """
    query_embedding = np.array(get_embedding(query)).reshape(1, -1)
    _, indices = globals()[f"index{label}"].search(query_embedding, top_k)

    results = []
    for i in indices[0]:
        row = globals()[f"df{label}"].iloc[i]
        raw_prefix = [row["Law"], row["Chapter"], row["Section"]]
        prefix = " ".join(filter(pd.notna, raw_prefix)) 
        
        article = f"{prefix}\n{row['Article']}"
        results.append(article)

    return results

def similarity_search(query, top_k=3):
    """Search for similar articles given a query
    Args:
        query (str): input query
        top_k (int): number of articles to return
    Returns:
        list[str]: list of articles
    """
    query_embedding = np.array(get_embedding(query)).reshape(1, -1)
    _, indices = index.search(query_embedding, top_k)

    results = []
    for i in indices[0]:
        row = df.iloc[i]
        raw_prefix = [row["Law"], row["Chapter"], row["Section"]]
        prefix = " ".join(filter(pd.notna, raw_prefix)) 

        article = f"{prefix}\n{row['Article']}" if prefix else row["Article"]
        results.append(article)

    return results

def decompose_question(query, query_decomposition, tokenizer):
    """Break down a query to 3 simpler sub-queries
    Args:
        query (str): input query
        query_decomposition (Llama 3.2 Instruct fine-tuned): query decomposition model
        tokenizer: Llama 3.2 Instruct's tokenizer
    Returns:
        list[str]: list of sub-queries
    """
    system_prompt = f"""You are a helpful assistant that generates multiple sub-questions related to an input question.
    The goal is to break down the input into a set of 3 sub-problems / sub-questions that can be answered in isolation and must be understandable stand-alone questions.
    Generate multiple search queries related to: {query}
    
    **Respond format:**
    Write a short analysis of why the query needs decomposition and how it will be done to derive the final 3 decomposed sub-questions.
    [Sub-question 1, Sub-question 2, Sub-question 3]"""

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": query},
    ]

    with torch.no_grad():
        inputs = tokenizer.apply_chat_template(messages, tokenize=True, return_tensors="pt").to("cuda")
        output_ids = query_decomposition.generate(input_ids=inputs, max_new_tokens=512, use_cache=True)
        
        decoded_output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
        raw = re.search(r'\[([^\]]*)\](?!.*\[)', decoded_output, re.DOTALL).group(1)
        questions = [item.strip().strip("'") for item in raw.split(",")]
    #     del inputs
    #     del output_ids
    #     del decoded_output
    #     del raw
    

    # query_decomposition.to('cpu')
    # torch.cuda.empty_cache()
    # gc.collect()
        
    return questions


def query_ollama(payload):
    """Calls Ollama API to generate responses
    Args:
        payload (dict): {
            "model": id of model used to generate response,
            "messages": user's chat history,
            "stream": boolean value to determine if the chat is streamed,
            "keep_alive": how long the model will stay loaded into memory,
            "options": {
                "num_ctx": context length,
                "temperature": The temperature of the model,
                "top_k": Reduces the probability of generating nonsense,
                "top_p": Works together with top-k,
                }
            }
    Returns:
        chat_history (list[dict]): User's chat history
    """
    api_url = "http://localhost:11434/api/chat"  
    response = requests.post(api_url, json=payload)
    if response.status_code == 200:
        return response.json()["message"]["content"]
    else:
        return "Xin lỗi, có lỗi xảy ra khi gọi API."


def chatbot(query):
    global chat_history

    if not chat_history:  
        decompose_question_result = decompose_question(query, query_decomposition, tokenizer)
        # labels = [predict_label(q) for q in decompose_question_result]
        label = predict_label(query)

        # data1, data2, data3 = [similarity_search(decompose_question_result[i], labels[i]) if labels[i] != 6 else '' for i in range(len(decompose_question_result))]
        data1 = similarity_search_with_filter(query, label) if label != 6 else ''
        data2 = similarity_search(query)
        data3 = [similarity_search(query) for query in decompose_question_result]
        context = set(data1) | set(data2)
        for chunks in data3:
            for chunk in chunks:
                context.update(chunk)
        
        context_text = "\n".join(context)

        system_prompt = f"""Bạn là OpenAPI, một chatbot hỗ trợ pháp lý tại Việt Nam.
        Nhiệm vụ của bạn là trả lời một câu hỏi về pháp luật dựa trên ngữ cảnh sau đây.

        **Ngữ cảnh**: {context_text}

        **Vui lòng tuân thủ các yêu cầu sau**:
            1. **Luôn trả lời bằng tiếng Việt.** 
            2. **Trả lời ngắn gọn không lan man DƯỚI 100 TỪ và trình bày rõ ràng, dễ hiểu.**    
            3. **Chỉ sử dụng thông tin từ ngữ cảnh được cung cấp ở trên.** Tuyệt đối **không bịa đặt** thông tin. Nếu không thể trả lời dựa trên ngữ cảnh, hãy nói: "Xin lỗi, tôi không thể trả lời câu hỏi này của bạn."
            4. **Câu trả lời được dùng từ phần nào của ngữ cảnh thì phải trích dẫn nguồn**, quy tắc trích dẫn là nguồn bao gồm tên văn bản pháp luật (ví dụ như luật, nghị định, thông tư,...), chương, mục và điều khoản.  
                Ví dụ trích dẫn nguồn:  
                    - *Luật Hôn nhân và Gia đình, Chương II, Điều 8.*  
                    - *Bộ luật Lao động, Mục 3, Điều 34.*"""
            
        chat_history = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": query + " RESPONSE UNDER 150 TOKENS"}
        ]

        payload = {
            "model": 'gemma3:27b',
            "messages": chat_history,
            "stream": False,
            "keep_alive": 0,
            "options": {
                "num_ctx": 2048,
                "temperature": 0.0,
                "top_k": 64,
                "top_p": 0.9,
                }
            }
        
        response = query_ollama(payload=payload)
    else:
        system_prompt = f"""Bạn là OpenAPI, một chatbot hỗ trợ pháp lý tại Việt Nam.
        Bạn được được cung cấp một ngữ cảnh từ lịch sử cuộc trò chuyện với người dùng. Lịch sử trò chuyện này bao gồm các câu hỏi của người dùng, các Điều luật, bộ luật, thông tư etc. mà người dùng đã cung cấp kèm theo câu trả lời của chatbot cho mỗi câu hỏi.
        Nhiệm vụ của bạn là trả lời câu hỏi tiếp theo mà người dùng hỏi trong cuộc trò chuyện đó.

        **Vui lòng tuân thủ các yêu cầu sau**:
            1. **Luôn trả lời bằng tiếng Việt.**
            2. **Trả lời ngắn gọn không lan man DƯỚI 100 TỪ và trình bày rõ ràng, dễ hiểu.**     
            3. **Chỉ sử dụng thông tin từ ngữ cảnh được cung cấp. ** Tuyệt đối **không bịa đặt** thông tin. Nếu không thể trả lời dựa trên ngữ cảnh, hãy nói: "Xin lỗi, tôi không thể trả lời câu hỏi này của bạn."
            4. **Câu trả lời được dùng từ phần nào của ngữ cảnh thì phải trích dẫn nguồn**, quy tắc trích dẫn là nguồn bao gồm tên văn bản pháp luật (ví dụ như luật, nghị định, thông tư,...), chương, mục và điều khoản.  
                Ví dụ trích dẫn nguồn:  
                    - *Luật Hôn nhân và Gia đình, Chương II, Điều 8.*  
                    - *Bộ luật Lao động, Mục 3, Điều 34.*"""
        
        chat_history.extend([
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": query + " RESPONSE UNDER 150 TOKENS"}
        ])  

        payload = {
            "model": 'gemma3:27b',
            "messages": chat_history,
            "stream": False,
            "keep_alive": 0,
            "options": {
                "num_ctx": 3072,
                "temperature": 0.2,
                "top_k": 64,
                "top_p": 0.9,
                }
            }
        
        response = query_ollama(payload=payload)

    chat_history.append({"role": "assistant", "content": response})  

    return chat_history

def reset_chat():
    global chat_history
    # query_decomposition.to('cuda')
    chat_history = []
    return []

with gr.Blocks(theme="soft") as demo:
    gr.Markdown("<h2 style='text-align: center;'>Trợ lý Pháp luật Việt Nam 🇻🇳</h2>", elem_id="title")

    with gr.Column():
        chatbot_ui = gr.Chatbot(label="Trợ lý Pháp luật", type="messages", elem_id="chatbot", height=700)

    with gr.Row(elem_id="bottom_section"):
        query_input = gr.Textbox(placeholder="Nhập câu hỏi của bạn...", label="Câu hỏi", elem_id="input_box")

    with gr.Row():
        submit_btn = gr.Button(" ↗️ Gửi", elem_id="send_btn")
        reset_btn = gr.Button("  🔄 Đoạn chat mới", elem_id="reset_btn")

    submit_btn.click(chatbot, inputs=query_input, outputs=chatbot_ui)
    reset_btn.click(reset_chat, outputs=chatbot_ui)

    gr.Markdown("<p style='text-align: center; font-size: 12px; color: gray;'>🚀 Được phát triển bởi nhóm OPENAPI để hỗ trợ pháp luật</p>")

demo.launch(share=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://0ddb6124093fd9b237.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0ddb6124093fd9b237.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Evaluate multiple choices

# %%
import os
import re
import numpy as np
import pandas as pd
import gradio as gr
import torch
import faiss
import requests
import torch.nn.functional as F

from transformers import AutoModelForCausalLM, AutoTokenizer, AutoModelForSequenceClassification
from sentence_transformers import SentenceTransformer

# Load models

tokenizer = AutoTokenizer.from_pretrained("phmtung/dpl302m-model")
query_decomposition = AutoModelForCausalLM.from_pretrained("phmtung/dpl302m-model", device_map='cuda')
query_decomposition.eval()

embedder = SentenceTransformer('dangvantuan/vietnamese-document-embedding', trust_remote_code=True)

classifi_model_path = "./phobert_finetuned"
classifi_model = AutoModelForSequenceClassification.from_pretrained(classifi_model_path, device_map='cuda')
classifi_tokenizer = AutoTokenizer.from_pretrained(classifi_model_path)
classifi_model.eval()

# Load faiss index and datastore
index = faiss.read_index('faiss.index')
df = pd.read_csv("chunks.csv")
df_folder = 'data_with_label'
faiss_index_folder = 'faiss_index'

dfs = sorted([f for f in os.listdir(df_folder) if not f.startswith('.')])
index_files = sorted([f for f in os.listdir(faiss_index_folder) if not f.startswith('.')])

for i in range(1, 6):
    globals()[f"df{i}"] = pd.read_csv(f"{df_folder}/{dfs[i-1]}")
    globals()[f"index{i}"] = faiss.read_index(f"{faiss_index_folder}/{index_files[i-1]}")

# Chat history storage
chat_history = []

###  HELPER FUNCTIONS  ###

def predict_label(query):
    """Predict law label of a given query
    Args:
        text (str): input query
    Returns:
        int: predicted label
    """
    inputs = classifi_tokenizer(query, return_tensors="pt", truncation=True, padding="max_length", max_length=128).to('cuda')
    
    with torch.no_grad():
        outputs = classifi_model(**inputs)
        
    logits = outputs.logits
    probs = F.softmax(logits, dim=-1)
    
    predicted_label = torch.argmax(probs, dim=-1).item()

    label_mapping = {0: "Trẻ em", 1: "Bình đẳng giới", 2: "Dân số", 3: "Hôn nhân và gia đình", 4: "Phòng, chống bạo lực gia đình", 5: "Khác"}

    return predicted_label+1

def get_embedding(query):
    """Get embedding of a given query
    Args:
        query (str): input query
    Returns:
        np.array: query embedding
    """
    return embedder.encode(query)


def similarity_search_with_filter(query, label, top_k=3):
    """Search for similar articles given a query and label
    Args:
        query (str): input query
        label (int): predicted label
        top_k (int): number of articles to return
    Returns:
        list[str]: list of articles
    """
    query_embedding = np.array(get_embedding(query)).reshape(1, -1)
    _, indices = globals()[f"index{label}"].search(query_embedding, top_k)

    results = []
    for i in indices[0]:
        row = globals()[f"df{label}"].iloc[i]
        raw_prefix = [row["Law"], row["Chapter"], row["Section"]]
        prefix = " ".join(filter(pd.notna, raw_prefix)) 
        
        article = f"{prefix}\n{row['Article']}"
        results.append(article)

    return results

def similarity_search(query, top_k=3):
    """Search for similar articles given a query
    Args:
        query (str): input query
        top_k (int): number of articles to return
    Returns:
        list[str]: list of articles
    """
    query_embedding = np.array(get_embedding(query)).reshape(1, -1)
    _, indices = index.search(query_embedding, top_k)

    results = []
    for i in indices[0]:
        row = df.iloc[i]
        raw_prefix = [row["Law"], row["Chapter"], row["Section"]]
        prefix = " ".join(filter(pd.notna, raw_prefix)) 

        article = f"{prefix}\n{row['Article']}" if prefix else row["Article"]
        results.append(article)

    return results

def decompose_question(query, query_decomposition, tokenizer):
    """Break down a query to 3 simpler sub-queries
    Args:
        query (str): input query
        query_decomposition (Llama 3.2 Instruct fine-tuned): query decomposition model
        tokenizer: Llama 3.2 Instruct's tokenizer
    Returns:
        list[str]: list of sub-queries
    """
    system_prompt = f"""You are a helpful assistant that generates multiple sub-questions related to an input question.
    The goal is to break down the input into a set of 3 sub-problems / sub-questions that can be answered in isolation and must be understandable stand-alone questions.
    Generate multiple search queries related to: {query}
    
    **Respond format:**
    Write a short analysis of why the query needs decomposition and how it will be done to derive the final 3 decomposed sub-questions.
    [Sub-question 1, Sub-question 2, Sub-question 3]"""

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": query},
    ]

    with torch.no_grad():
        inputs = tokenizer.apply_chat_template(messages, tokenize=True, return_tensors="pt").to("cuda")
        output_ids = query_decomposition.generate(input_ids=inputs, max_new_tokens=512, use_cache=True)
        
        decoded_output = tokenizer.decode(output_ids[0], skip_special_tokens=True)
        raw = re.search(r'\[([^\]]*)\](?!.*\[)', decoded_output, re.DOTALL).group(1)
        questions = [item.strip().strip("'") for item in raw.split(",")]
    #     del inputs
    #     del output_ids
    #     del decoded_output
    #     del raw
    

    # query_decomposition.to('cpu')
    # torch.cuda.empty_cache()
    # gc.collect()
        
    return questions


def query_ollama(payload):
    """Calls Ollama API to generate responses
    Args:
        payload (dict): {
            "model": id of model used to generate response,
            "messages": user's chat history,
            "stream": boolean value to determine if the chat is streamed,
            "keep_alive": how long the model will stay loaded into memory,
            "options": {
                "num_ctx": context length,
                "temperature": The temperature of the model,
                "top_k": Reduces the probability of generating nonsense,
                "top_p": Works together with top-k,
                }
            }
    Returns:
        chat_history (list[dict]): User's chat history
    """
    api_url = "http://localhost:11434/api/chat"  
    response = requests.post(api_url, json=payload)
    if response.status_code == 200:
        return response.json()["message"]["content"]
    else:
        return "Xin lỗi, có lỗi xảy ra khi gọi API."


def chatbot(query):
    global chat_history

    if not chat_history:  
        decompose_question_result = decompose_question(query, query_decomposition, tokenizer)
        # labels = [predict_label(q) for q in decompose_question_result]
        label = predict_label(query)

        # data1, data2, data3 = [similarity_search(decompose_question_result[i], labels[i]) if labels[i] != 6 else '' for i in range(len(decompose_question_result))]
        data1 = similarity_search_with_filter(query, label) if label != 6 else ''
        data2 = similarity_search(query)
        data3 = [similarity_search(query) for query in decompose_question_result]
        context = set(data1) | set(data2)
        for chunks in data3:
            for chunk in chunks:
                context.update(chunk)
        
        context_text = "\n".join(context)

        system_prompt = f"""Bạn là OpenAPI, một chatbot hỗ trợ pháp lý tại Việt Nam.
        Nhiệm vụ của bạn là trả lời các câu hỏi chắc nhiệm gồm các đáp án A, B, C và D về các văn bản quy phạm pháp luật dựa trên ngữ cảnh sau đây và kết hợp với lịch sử trò chuyện.
        Ngữ cảnh: {context_text}
        Vui lòng tuân thủ yêu cầu sau:
            1. **Chỉ trả lời A, B, C hoặc D. Không đề cập thêm bất cứ thông tin gì**"""
            
        chat_history = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": query }
        ]

        payload = {
            "model": 'gemma3:27b',
            "messages": chat_history,
            "stream": False,
            "keep_alive": 0,
            "options": {
                "num_ctx": 2048,
                "temperature": 0.0,
                "top_k": 64,
                "top_p": 0.9,
                }
            }
        
        response = query_ollama(payload=payload)
    else:
        system_prompt = f"""Bạn là OpenAPI, một chatbot hỗ trợ pháp lý tại Việt Nam.
        Bạn được được cung cấp một ngữ cảnh từ lịch sử cuộc trò chuyện với người dùng. Lịch sử trò chuyện này bao gồm các câu hỏi của người dùng, các Điều luật, bộ luật, thông tư etc. mà người dùng đã cung cấp kèm theo câu trả lời của chatbot cho mỗi câu hỏi.
        Nhiệm vụ của bạn là trả lời câu hỏi tiếp theo mà người dùng hỏi trong cuộc trò chuyện đó.

        **Vui lòng tuân thủ các yêu cầu sau**:
            1. **Luôn trả lời bằng tiếng Việt.**
            2. **Trả lời ngắn gọn không lan man DƯỚI 100 TỪ và trình bày rõ ràng, dễ hiểu.**     
            3. **Chỉ sử dụng thông tin từ ngữ cảnh được cung cấp. ** Tuyệt đối **không bịa đặt** thông tin. Nếu không thể trả lời dựa trên ngữ cảnh, hãy nói: "Xin lỗi, tôi không thể trả lời câu hỏi này của bạn."
            4. **Câu trả lời được dùng từ phần nào của ngữ cảnh thì phải trích dẫn nguồn**, quy tắc trích dẫn là nguồn bao gồm tên văn bản pháp luật (ví dụ như luật, nghị định, thông tư,...), chương, mục và điều khoản.  
                Ví dụ trích dẫn nguồn:  
                    - *Luật Hôn nhân và Gia đình, Chương II, Điều 8.*  
                    - *Bộ luật Lao động, Mục 3, Điều 34.*"""
        
        chat_history.extend([
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": query + " RESPONSE UNDER 150 TOKENS"}
        ])  

        payload = {
            "model": 'gemma3:27b',
            "messages": chat_history,
            "stream": False,
            "keep_alive": 0,
            "options": {
                "num_ctx": 3072,
                "temperature": 0.2,
                "top_k": 64,
                "top_p": 0.9,
                }
            }
        
        response = query_ollama(payload=payload)

    chat_history.append({"role": "assistant", "content": response})  

    return chat_history

def reset_chat():
    global chat_history
    # query_decomposition.to('cuda')
    chat_history = []
    return []

with gr.Blocks(theme="soft") as demo:
    gr.Markdown("<h2 style='text-align: center;'>Trợ lý Pháp luật Việt Nam 🇻🇳</h2>", elem_id="title")

    with gr.Column():
        chatbot_ui = gr.Chatbot(label="Trợ lý Pháp luật", type="messages", elem_id="chatbot", height=700)

    with gr.Row(elem_id="bottom_section"):
        query_input = gr.Textbox(placeholder="Nhập câu hỏi của bạn...", label="Câu hỏi", elem_id="input_box")

    with gr.Row():
        submit_btn = gr.Button(" ↗️ Gửi", elem_id="send_btn")
        reset_btn = gr.Button("  🔄 Đoạn chat mới", elem_id="reset_btn")

    submit_btn.click(chatbot, inputs=query_input, outputs=chatbot_ui)
    reset_btn.click(reset_chat, outputs=chatbot_ui)

    gr.Markdown("<p style='text-align: center; font-size: 12px; color: gray;'>🚀 Được phát triển bởi nhóm OPENAPI để hỗ trợ pháp luật</p>")

demo.launch(share=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://16c0fdde70ecea2629.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://16c0fdde70ecea2629.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
